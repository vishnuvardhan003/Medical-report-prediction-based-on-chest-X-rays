# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import xml.etree.ElementTree as ET
import os
import cv2
import tensorflow as tf
from wordcloud import WordCloud
import re
from collections import defaultdict
import itertools
from collections import Counter
from PIL import Image, ImageDraw, ImageFont

# %%
directory = 'reports/ecgen-radiology'

# %%
# extracting data from the xml documents
img = []
img_impression = []
img_finding = []
for filename in tqdm(os.listdir(directory)):
    if filename.endswith(".xml"):
        f = directory + '/' + filename
        tree = ET.parse(f)
        root = tree.getroot()
        for child in root:
            if child.tag == 'MedlineCitation':
                for attr in child:
                    if attr.tag == 'Article':
                        for i in attr:
                            if i.tag == 'Abstract':
                                for name in i:
                                    if name.get('Label') == 'FINDINGS':
                                        finding=name.text
                                        
        for p_image in root.findall('parentImage'):
            
            img.append(p_image.get('id'))
            img_finding.append(finding)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 3955/3955 [00:02<00:00, 1494.84it/s]

# %%
dataset = pd.DataFrame()
dataset['Image_path'] = img
dataset['Finding'] = img_finding

# %%
dataset.head(10)
# Out:
#              Image_path                                            Finding
# 0   CXR1_1_IM-0001-3001  The cardiac silhouette and mediastinum size ar...
# 1   CXR1_1_IM-0001-4001  The cardiac silhouette and mediastinum size ar...
# 2    CXR10_IM-0002-1001  The cardiomediastinal silhouette is within nor...
# 3    CXR10_IM-0002-2001  The cardiomediastinal silhouette is within nor...
# 4   CXR100_IM-0002-1001  Both lungs are clear and expanded. Heart and m...
# 5   CXR100_IM-0002-2001  Both lungs are clear and expanded. Heart and m...
# 6  CXR1000_IM-0003-1001  There is XXXX increased opacity within the rig...
# 7  CXR1000_IM-0003-2001  There is XXXX increased opacity within the rig...
# 8  CXR1000_IM-0003-3001  There is XXXX increased opacity within the rig...
# 9  CXR1001_IM-0004-1001  Interstitial markings are diffusely prominent ...

# %%
print('Dataset Shape:', dataset.shape)
# Out:
# Dataset Shape: (7470, 2)

# %%
def absolute_path(x):
    '''Makes the path absolute '''
    x = 'images/'+ x + '.png'
    return x

# %%
dataset['Image_path'] = dataset['Image_path'].apply(lambda x : absolute_path(x)) # making the paths absolute

# %%
def image_desc_plotter(data, n, rep):  
    count = 1  
    fig = plt.figure(figsize=(10,20))

    if rep == 'finding':
        
        for filename in data['Image_path'].values[95:100]:   
        
            findings = list(data["Finding"].loc[data["Image_path"] == filename].values) 
            img = cv2.imread(filename)    
            ax = fig.add_subplot(n, 2 , count , xticks=[], yticks=[])  
            ax.imshow(img)     
            count += 1            
            ax = fig.add_subplot(n ,2 ,count)   
            plt.axis('off')     
            ax.plot()     
            ax.set_xlim(0,1)    
            ax.set_ylim(0, len(findings))  
            for i, f in enumerate(findings):   
                ax.text(0,i,f,fontsize=20)   
            count += 1 
        plt.show()
        
    else:
        print("Enter a valid String")

# %%
image_desc_plotter(dataset, 5, 'finding')

# %%
# loading the heights and widths of each image
h = []
w = []
for i in tqdm(np.unique(dataset['Image_path'].values)):
    img = cv2.imread(i)
    h.append(img.shape[0])
    w.append(img.shape[0])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 7470/7470 [00:33<00:00, 219.86it/s]

# %%
plt.figure(figsize=(10,4))
plt.subplot(121)
plt.title('Height Plot')
plt.ylabel('Heights')
plt.xlabel('--Images--')
sns.scatterplot(range(len(h)), h)
plt.subplot(122)
plt.title('Width Plot')
plt.ylabel('Widths')
plt.xlabel('--Images--')
sns.scatterplot(range(len(w)), h)
# Out:
# C:\Users\DELL\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Width Plot'}, xlabel='--Images--', ylabel='Widths'>

# %% [markdown]
# Images have different heights and widths, they will be resized into a common shape

# %%
print('Number of Images:', dataset['Image_path'].nunique())
# Out:
# Number of Images: 7470

# %%
# number of missing values
dataset.isnull().sum()
# Out:
# Image_path      0
# Finding       997
# dtype: int64

# %% [markdown]
# There are a total of 997 rows where 'findings' column has no value. We can simply drop them.

# %%
dataset = dataset.dropna(axis=0) # drop all missing value rows

# %%
dataset.isnull().sum()
# Out:
# Image_path    0
# Finding       0
# dtype: int64

# %%
print('New Shape of the Data:', dataset.shape)
# Out:
# New Shape of the Data: (6473, 2)

# %%
dataset.head(10)
# Out:
#                         Image_path  \
# 0   images/CXR1_1_IM-0001-3001.png
# 1   images/CXR1_1_IM-0001-4001.png
# 2    images/CXR10_IM-0002-1001.png
# 3    images/CXR10_IM-0002-2001.png
# 4   images/CXR100_IM-0002-1001.png
# 5   images/CXR100_IM-0002-2001.png
# 6  images/CXR1000_IM-0003-1001.png
# 7  images/CXR1000_IM-0003-2001.png
# 8  images/CXR1000_IM-0003-3001.png
# 9  images/CXR1001_IM-0004-1001.png
#
#                                              Finding
# 0  The cardiac silhouette and mediastinum size ar...
# 1  The cardiac silhouette and mediastinum size ar...
# 2  The cardiomediastinal silhouette is within nor...
# 3  The cardiomediastinal silhouette is within nor...
# 4  Both lungs are clear and expanded. Heart and m...
# 5  Both lungs are clear and expanded. Heart and m...
# 6  There is XXXX increased opacity within the rig...
# 7  There is XXXX increased opacity within the rig...
# 8  There is XXXX increased opacity within the rig...
# 9  Interstitial markings are diffusely prominent ...

# %%
plt.figure(figsize=(14,7))
plt.subplot(131)
img1 = cv2.imread(dataset['Image_path'].values[6])
plt.imshow(img1)
plt.title(dataset['Image_path'].values[6])
plt.subplot(132)
img2 = cv2.imread(dataset['Image_path'].values[7])
plt.title(dataset['Image_path'].values[7])
plt.imshow(img2)
plt.subplot(133)
img3 = cv2.imread(dataset['Image_path'].values[8])
plt.title(dataset['Image_path'].values[8])
plt.imshow(img3)

# %%
dataset['Finding'].values[6], dataset['Finding'].values[7], dataset['Finding'].values[8]
# Out:
# ('There is XXXX increased opacity within the right upper lobe with possible mass and associated area of atelectasis or focal consolidation. The cardiac silhouette is within normal limits. XXXX opacity in the left midlung overlying the posterior left 5th rib may represent focal airspace disease. No pleural effusion or pneumothorax. No acute bone abnormality.',
#  'There is XXXX increased opacity within the right upper lobe with possible mass and associated area of atelectasis or focal consolidation. The cardiac silhouette is within normal limits. XXXX opacity in the left midlung overlying the posterior left 5th rib may represent focal airspace disease. No pleural effusion or pneumothorax. No acute bone abnormality.',
#  'There is XXXX increased opacity within the right upper lobe with possible mass and associated area of atelectasis or focal consolidation. The cardiac silhouette is within normal limits. XXXX opacity in the left midlung overlying the posterior left 5th rib may represent focal airspace disease. No pleural effusion or pneumothorax. No acute bone abnormality.')

# %% [markdown]
# The above two findings are same since its of the same person. The images are also of the same person but scanned at different views.

# %% [markdown]
# ## The dataset consists of multiple chest shots of the same person. The images of a person has the same file name except the last 4 digits. Therefore that can be taken as the person ID.

# %%
# This creates 2 dictionaries with keys as the person id and the number of images and findings for that person. 
images = {}
findings = {}
for img, fin in dataset.values:
    a = img.split('-')
    a.pop(len(a)-1)
    a = '-'.join(e for e in a)
    if a not in images.keys():
        images[a] = 1
        findings[a] = fin
    else:
        images[a] += 1
        findings[a] = fin

# %%
images['images/CXR1001_IM-0004'], findings['images/CXR1001_IM-0004']
# Out:
# (2,
#  'Interstitial markings are diffusely prominent throughout both lungs. Heart size is normal. Pulmonary XXXX normal.')

# %%
print('Total Number of Unique_IDs :', len(images.keys()))
# Out:
# Total Number of Unique_IDs : 3350

# %% [markdown]
# The dataset contains images of 3350 different people

# %%
plt.figure(figsize=(17,5))
plt.bar(range(len(images.keys())), images.values())
plt.ylabel('Total Images per individual')
plt.xlabel('Number of Individuals in the Data')
# Out:
# Text(0.5, 0, 'Number of Individuals in the Data')

# %%
one = 0
two = 0
three = 0
four = 0
for v in images.values():
    if v == 1:
        one +=1
    elif v == 2:
        two += 1
    elif v == 3:
        three += 1
    elif v == 4:
        four += 1
    else:
        print('Error')

# %%
one, two, three, four
# Out:
# (390, 2807, 143, 10)

# %% [markdown]
# The above variables one, two, three, four contains the total number of IDs with 1,2,3,4 number of images respectively.
#
# As we can see there are multiple images corresponding to a single person. These are different chest scans at different views. Most of the individuals have only 2 scans while the highest being 4.

# %%
images
# Out:
# {'images/CXR1_1_IM-0001': 2,
#  'images/CXR10_IM-0002': 2,
#  'images/CXR100_IM-0002': 2,
#  'images/CXR1000_IM-0003': 3,
#  'images/CXR1001_IM-0004': 2,
#  'images/CXR1003_IM-0005': 1,
#  'images/CXR1004_IM-0005': 2,
#  'images/CXR1005_IM-0006': 2,
#  'images/CXR1006_IM-0007': 2,
#  'images/CXR1007_IM-0008': 3,
#  'images/CXR1008_IM-0009': 2,
#  'images/CXR1009_IM-0010': 2,
#  'images/CXR101_IM-0011': 2,
#  'images/CXR1010_IM-0012': 2,
#  'images/CXR1011_IM-0013': 2,
#  'images/CXR1012_IM-0013': 1,
#  'images/CXR1013_IM-0013': 2,
#  'images/CXR1015_IM-0001': 2,
#  'images/CXR1015_IM-0013': 2,
#  'images/CXR1017_IM-0013': 2,
#  'images/CXR1018_IM-0014': 2,
#  'images/CXR1019_IM-0015': 2,
#  'images/CXR102_IM-0016': 2,
#  'images/CXR1020_IM-0017': 2,
#  'images/CXR1022_IM-0017': 2,
#  'images/CXR1023_IM-0018': 2,
#  'images/CXR1024_IM-0019': 1,
#  'images/CXR1025_IM-0020': 2,
#  'images/CXR1026_IM-0021': 1,
#  'images/CXR1027_IM-0021': 2,
#  'images/CXR1028_IM-0022': 2,
#  'images/CXR103_IM-0023': 2,
#  'images/CXR1030_IM-0024': 2,
#  'images/CXR1032_IM-0026-1001': 2,
#  'images/CXR1033_IM-0027': 2,
#  'images/CXR1034_IM-0028': 2,
#  'images/CXR1035_IM-0028': 2,
#  'images/CXR1036_IM-0029': 1,
#  'images/CXR1037_IM-0029': 2,
#  'images/CXR1039_IM-0030': 1,
#  'images/CXR104_IM-0031-0001': 1,
#  'images/CXR1041_IM-0033': 2,
#  'images/CXR1042_IM-0034': 2,
#  'images/CXR1043_IM-0035-0001': 2,
#  'images/CXR1044_IM-0036': 2,
#  'images/CXR1045_IM-0036': 2,
#  'images/CXR1046_IM-0036': 2,
#  'images/CXR1047_IM-0036': 2,
#  'images/CXR1048_IM-0036': 2,
#  'images/CXR105_IM-0037': 2,
#  'images/CXR1050_IM-0038': 2,
#  'images/CXR1051_IM-0039': 2,
#  'images/CXR1052_IM-0040': 2,
#  'images/CXR1053_IM-0040': 2,
#  'images/CXR1054_IM-0040': 2,
#  'images/CXR1055_IM-0040': 2,
#  'images/CXR1056_IM-0040': 3,
#  'images/CXR1057_IM-0041': 2,
#  'images/CXR1058_IM-0041': 2,
#  'images/CXR1059_IM-0041': 1,
#  'images/CXR106_IM-0042': 2,
#  'images/CXR1060_IM-0042': 2,
#  'images/CXR1061_IM-0043': 2,
#  'images/CXR1062_IM-0043': 1,
#  'images/CXR1063_IM-0044': 2,
#  'images/CXR1064_IM-0045': 1,
#  'images/CXR1065_IM-0046': 2,
#  'images/CXR1067_IM-0048': 2,
#  'images/CXR1069_IM-0049': 1,
#  'images/CXR107_IM-0049': 2,
#  'images/CXR1070_IM-0050': 2,
#  'images/CXR1071_IM-0051': 1,
#  'images/CXR1072_IM-0052-1001': 2,
#  'images/CXR1073_IM-0053': 2,
#  'images/CXR1074_IM-0054': 2,
#  'images/CXR1075_IM-0054': 2,
#  'images/CXR1076_IM-0054': 2,
#  'images/CXR1077_IM-0054': 2,
#  'images/CXR1078_IM-0055': 2,
#  'images/CXR1079_IM-0056': 2,
#  'images/CXR108_IM-0056': 2,
#  'images/CXR1081_IM-0057': 1,
#  'images/CXR1082_IM-0058': 1,
#  'images/CXR1083_IM-0058': 2,
#  'images/CXR1084_IM-0058': 2,
#  'images/CXR1085_IM-0059': 2,
#  'images/CXR1086_IM-0059': 2,
#  'images/CXR1087_IM-0060': 2,
#  'images/CXR1088_IM-0061': 2,
#  'images/CXR1089_IM-0061': 2,
#  'images/CXR1091_IM-0062': 2,
#  'images/CXR1092_IM-0063': 2,
#  'images/CXR1093_IM-0064': 2,
#  'images/CXR1094_IM-0065': 2,
#  'images/CXR1095_IM-0066': 1,
#  'images/CXR1096_IM-0066': 1,
#  'images/CXR1097_IM-0067': 2,
#  'images/CXR1098_IM-0067': 1,
#  'images/CXR1099_IM-0067': 2,
#  'images/CXR11_IM-0067': 2,
#  'images/CXR110_IM-0067': 2,
#  'images/CXR1100_IM-0068': 2,
#  'images/CXR1101_IM-0068': 3,
#  'images/CXR1102_IM-0069': 4,
#  'images/CXR1103_IM-0070': 2,
#  'images/CXR1105_IM-0072-1001': 2,
#  'images/CXR1108_IM-0075': 2,
#  'images/CXR1109_IM-0076': 2,
#  'images/CXR1110_IM-0076': 2,
#  'images/CXR1111_IM-0077': 2,
#  'images/CXR1112_IM-0078': 2,
#  'images/CXR1113_IM-0078': 2,
#  'images/CXR1114_IM-0079': 2,
#  'images/CXR1115_IM-0079': 1,
#  'images/CXR1116_IM-0079': 2,
#  'images/CXR1117_IM-0079': 2,
#  'images/CXR1118_IM-0079': 2,
#  'images/CXR1119_IM-0080': 2,
#  'images/CXR112_IM-0080': 2,
#  'images/CXR1120_IM-0080': 1,
#  'images/CXR1121_IM-0080': 2,
#  'images/CXR1122_IM-0080-1001': 2,
#  'images/CXR1122_IM-0080': 1,
#  'images/CXR1123_IM-0080': 2,
#  'images/CXR1124_IM-0081': 2,
#  'images/CXR1125_IM-0082': 2,
#  'images/CXR1126_IM-0082': 2,
#  'images/CXR1129_IM-0085': 1,
#  'images/CXR113_IM-0086': 3,
#  'images/CXR1130_IM-0087': 2,
#  'images/CXR1131_IM-0088-0001': 2,
#  'images/CXR1133_IM-0090': 2,
#  'images/CXR1134_IM-0091': 2,
#  'images/CXR1135_IM-0091': 2,
#  'images/CXR1136_IM-0092': 2,
#  'images/CXR1138_IM-0094': 2,
#  'images/CXR1139_IM-0095': 2,
#  'images/CXR114_IM-0096': 2,
#  'images/CXR1141_IM-0096': 2,
#  'images/CXR1144_IM-0097': 2,
#  'images/CXR1145_IM-0097': 2,
#  'images/CXR1146_IM-0098': 2,
#  'images/CXR1148_IM-0100': 2,
#  'images/CXR1149_IM-0101': 2,
#  'images/CXR115_IM-0102': 2,
#  'images/CXR1150_IM-0102': 1,
#  'images/CXR1151_IM-0102': 2,
#  'images/CXR1152_IM-0103': 2,
#  'images/CXR1153_IM-0104': 2,
#  'images/CXR1154_IM-0104': 2,
#  'images/CXR1155_IM-0105-0001': 1,
#  'images/CXR1157_IM-0106': 2,
#  'images/CXR1158_IM-0107': 2,
#  'images/CXR1159_IM-0107': 1,
#  'images/CXR116_IM-0107': 2,
#  'images/CXR1160_IM-0107': 2,
#  'images/CXR1161_IM-0107': 2,
#  'images/CXR1163_IM-0108': 2,
#  'images/CXR1165_IM-0110': 1,
#  'images/CXR1166_IM-0111': 2,
#  'images/CXR1167_IM-0112': 2,
#  'images/CXR1168_IM-0112': 2,
#  'images/CXR1169_IM-0113-0001': 1,
#  'images/CXR1170_IM-0115': 3,
#  'images/CXR1171_IM-0116': 2,
#  'images/CXR1172_IM-0117': 1,
#  'images/CXR1173_IM-0118': 2,
#  'images/CXR1174_IM-0118': 2,
#  'images/CXR1175_IM-0119': 2,
#  'images/CXR1176_IM-0119': 2,
#  'images/CXR1177_IM-0120': 2,
#  'images/CXR1178_IM-0121': 2,
#  'images/CXR1179_IM-0122': 2,
#  'images/CXR118_IM-0123': 2,
#  'images/CXR1180_IM-0123': 2,
#  'images/CXR1182_IM-0124': 2,
#  'images/CXR1184_IM-0124': 2,
#  'images/CXR1187_IM-0126': 2,
#  'images/CXR1188_IM-0127': 2,
#  'images/CXR1189_IM-0128': 2,
#  'images/CXR119_IM-0128': 1,
#  'images/CXR1190_IM-0128': 3,
#  'images/CXR1191_IM-0128': 2,
#  'images/CXR1192_IM-0129': 2,
#  'images/CXR1193_IM-0129': 2,
#  'images/CXR1195_IM-0131': 2,
#  'images/CXR1196_IM-0131': 2,
#  'images/CXR1197_IM-0131': 2,
#  'images/CXR1199_IM-0133': 2,
#  'images/CXR12_IM-0133': 2,
#  'images/CXR120_IM-0133': 2,
#  'images/CXR1200_IM-0134': 2,
#  'images/CXR1202_IM-0136': 2,
#  'images/CXR1203_IM-0137': 2,
#  'images/CXR1204_IM-0138': 2,
#  'images/CXR1205_IM-0138': 2,
#  'images/CXR1207_IM-0140-0001': 2,
#  'images/CXR1208_IM-0141': 3,
#  'images/CXR1209_IM-0142': 2,
#  'images/CXR121_IM-0142': 2,
#  'images/CXR1210_IM-0142': 2,
#  'images/CXR1211_IM-0142': 2,
#  'images/CXR1212_IM-0143': 2,
#  'images/CXR1213_IM-0144': 2,
#  'images/CXR1214_IM-0144': 2,
#  'images/CXR1216_IM-0144': 1,
#  'images/CXR1217_IM-0145-0001': 2,
#  'images/CXR1218_IM-0146': 2,
#  'images/CXR1219_IM-0146': 2,
#  'images/CXR1220_IM-0148': 3,
#  'images/CXR1221_IM-0149-0001': 2,
#  'images/CXR1222_IM-0150': 2,
#  'images/CXR1223_IM-0150': 2,
#  'images/CXR1224_IM-0150': 1,
#  'images/CXR1225_IM-0150': 2,
#  'images/CXR1226_IM-0150': 2,
#  'images/CXR1229_IM-0152': 2,
#  'images/CXR123_IM-0153': 2,
#  'images/CXR1231_IM-0155': 2,
#  'images/CXR1232_IM-0156': 2,
#  'images/CXR1233_IM-0157': 2,
#  'images/CXR1234_IM-0157': 2,
#  'images/CXR1235_IM-0158': 2,
#  'images/CXR1236_IM-0158': 2,
#  'images/CXR1237_IM-0159': 2,
#  'images/CXR1238_IM-0160': 1,
#  'images/CXR1240_IM-0162': 2,
#  'images/CXR1241_IM-0163': 1,
#  'images/CXR1242_IM-0164': 2,
#  'images/CXR1243_IM-0165': 3,
#  'images/CXR1244_IM-0166': 2,
#  'images/CXR1246_IM-0167': 2,
#  'images/CXR1248_IM-0168': 2,
#  'images/CXR1249_IM-0169': 2,
#  'images/CXR125_IM-0169': 2,
#  'images/CXR1250_IM-0169': 2,
#  'images/CXR1253_IM-0171-0001': 2,
#  'images/CXR1254_IM-0172': 2,
#  'images/CXR1255_IM-0172-1001': 2,
#  'images/CXR1256_IM-0173': 2,
#  'images/CXR1257_IM-0174': 2,
#  'images/CXR1258_IM-0175': 1,
#  'images/CXR1259_IM-0175': 2,
#  'images/CXR126_IM-0176': 1,
#  'images/CXR1261_IM-0177': 2,
#  'images/CXR1262_IM-0178': 3,
#  'images/CXR1263_IM-0179': 2,
#  'images/CXR1264_IM-0179': 2,
#  'images/CXR1265_IM-0179': 2,
#  'images/CXR1266_IM-0179': 2,
#  'images/CXR1267_IM-0179': 2,
#  'images/CXR1268_IM-0180': 2,
#  'images/CXR1269_IM-0181': 2,
#  'images/CXR127_IM-0181': 2,
#  'images/CXR1270_IM-0181': 2,
#  'images/CXR1271_IM-0182': 2,
#  'images/CXR1272_IM-0183': 2,
#  'images/CXR1273_IM-0183': 2,
#  'images/CXR1274_IM-0183': 2,
#  'images/CXR1276_IM-0184': 3,
#  'images/CXR1277_IM-0185': 2,
#  'images/CXR1278_IM-0185': 2,
#  'images/CXR1279_IM-0185': 1,
#  'images/CXR128_IM-0186': 2,
#  'images/CXR1280_IM-0187': 2,
#  'images/CXR1281_IM-0188': 1,
#  'images/CXR1282_IM-0188': 2,
#  'images/CXR1283_IM-0188': 1,
#  'images/CXR1284_IM-0188': 1,
#  'images/CXR1285_IM-0188': 3,
#  'images/CXR1287_IM-0188': 2,
#  'images/CXR1288_IM-0189': 2,
#  'images/CXR1289_IM-0189': 2,
#  'images/CXR129_IM-0189': 2,
#  'images/CXR1290_IM-0189': 1,
#  'images/CXR1291_IM-0190': 2,
#  'images/CXR1292_IM-0191': 2,
#  'images/CXR1294_IM-0193': 2,
#  'images/CXR1295_IM-0194': 2,
#  'images/CXR13_IM-0198': 2,
#  'images/CXR130_IM-0198': 1,
#  'images/CXR1300_IM-0198': 1,
#  'images/CXR1301_IM-0198': 2,
#  'images/CXR1302_IM-0198': 2,
#  'images/CXR1303_IM-0199-1001': 2,
#  'images/CXR1303_IM-0199-2001': 3,
#  'images/CXR1304_IM-0199': 2,
#  'images/CXR1305_IM-0199': 2,
#  'images/CXR1306_IM-0200': 2,
#  'images/CXR1307_IM-0200': 1,
#  'images/CXR1308_IM-0201': 2,
#  'images/CXR1309_IM-0201-1001': 2,
#  'images/CXR131_IM-0202': 2,
#  'images/CXR1310_IM-0202': 2,
#  'images/CXR1311_IM-0203': 2,
#  'images/CXR1313_IM-0204': 1,
#  'images/CXR1314_IM-0204': 2,
#  'images/CXR1315_IM-0204': 2,
#  'images/CXR1317_IM-0205': 2,
#  'images/CXR1318_IM-0205': 2,
#  'images/CXR1319_IM-0205': 2,
#  'images/CXR132_IM-0206': 1,
#  'images/CXR1320_IM-0207': 2,
#  'images/CXR1322_IM-0208': 1,
#  'images/CXR1323_IM-0209': 2,
#  'images/CXR1324_IM-0209': 2,
#  'images/CXR1327_IM-0211': 2,
#  'images/CXR1328_IM-0211': 1,
#  'images/CXR1329_IM-0211': 2,
#  'images/CXR133_IM-0212': 3,
#  'images/CXR1330_IM-0213': 2,
#  'images/CXR1331_IM-0213': 1,
#  'images/CXR1333_IM-0214': 2,
#  'images/CXR1334_IM-0214': 2,
#  'images/CXR1335_IM-0215': 2,
#  'images/CXR1336_IM-0216': 1,
#  'images/CXR1338_IM-0217': 1,
#  'images/CXR1339_IM-0218': 2,
#  'images/CXR134_IM-0219': 1,
#  'images/CXR1340_IM-0220': 2,
#  'images/CXR1341_IM-0220': 2,
#  'images/CXR1342_IM-0221': 2,
#  'images/CXR1343_IM-0222-0001': 2,
#  'images/CXR1344_IM-0223': 2,
#  'images/CXR1345_IM-0223': 2,
#  'images/CXR1346_IM-0224': 3,
#  'images/CXR1347_IM-0225': 2,
#  'images/CXR1348_IM-0226-4004': 2,
#  'images/CXR1349_IM-0227': 2,
#  'images/CXR135_IM-0227': 2,
#  'images/CXR1350_IM-0227': 2,
#  'images/CXR1352_IM-0229': 2,
#  'images/CXR1353_IM-0230': 2,
#  'images/CXR1354_IM-0230': 2,
#  'images/CXR1355_IM-0230': 2,
#  'images/CXR1356_IM-0231': 2,
#  'images/CXR1357_IM-0231': 1,
#  'images/CXR1358_IM-0232': 3,
#  'images/CXR1359_IM-0233': 2,
#  'images/CXR136_IM-0233': 2,
#  'images/CXR1360_IM-0234-0001': 2,
#  'images/CXR1363_IM-0236-0001': 2,
#  'images/CXR1364_IM-0237': 2,
#  'images/CXR1365_IM-0237': 2,
#  'images/CXR1366_IM-0237': 2,
#  'images/CXR1367_IM-0237': 2,
#  'images/CXR1368_IM-0237': 2,
#  'images/CXR1369_IM-0238': 2,
#  'images/CXR1370_IM-0239': 2,
#  'images/CXR1372_IM-0239': 2,
#  'images/CXR1373_IM-0240': 2,
#  'images/CXR1374_IM-0240': 2,
#  'images/CXR1376_IM-0242': 2,
#  'images/CXR1377_IM-0242': 2,
#  'images/CXR1378_IM-0242': 2,
#  'images/CXR1379_IM-0243': 2,
#  'images/CXR138_IM-0244': 2,
#  'images/CXR1380_IM-0245': 2,
#  'images/CXR1381_IM-0245': 2,
#  'images/CXR1382_IM-0245': 2,
#  'images/CXR1383_IM-0245': 2,
#  'images/CXR1384_IM-0246': 2,
#  'images/CXR1385_IM-0246': 2,
#  'images/CXR1386_IM-0246': 2,
#  'images/CXR1387_IM-0246': 1,
#  'images/CXR1388_IM-0246': 2,
#  'images/CXR139_IM-0248': 2,
#  'images/CXR1390_IM-0249': 2,
#  'images/CXR1391_IM-0250': 2,
#  'images/CXR1392_IM-0251': 2,
#  'images/CXR1393_IM-0251': 2,
#  'images/CXR1396_IM-0252': 2,
#  'images/CXR1398_IM-0254': 1,
#  'images/CXR1399_IM-0255': 2,
#  'images/CXR14_IM-0256': 2,
#  'images/CXR1400_IM-0256': 2,
#  'images/CXR1402_IM-0257': 3,
#  'images/CXR1403_IM-0258': 2,
#  'images/CXR1404_IM-0258': 2,
#  'images/CXR1405_IM-0259': 2,
#  'images/CXR1406_IM-0259': 2,
#  'images/CXR1407_IM-0260': 2,
#  'images/CXR1408_IM-0260': 1,
#  'images/CXR1409_IM-0260': 2,
#  'images/CXR141_IM-0260': 2,
#  'images/CXR1410_IM-0260': 2,
#  'images/CXR1411_IM-0261-0001': 2,
#  'images/CXR1412_IM-0262': 2,
#  'images/CXR1413_IM-0263': 2,
#  'images/CXR1415_IM-0264': 2,
#  'images/CXR1416_IM-0265': 2,
#  'images/CXR1417_IM-0266': 2,
#  'images/CXR1419_IM-0267': 2,
#  'images/CXR142_IM-0267': 2,
#  'images/CXR1421_IM-0269': 1,
#  'images/CXR1422_IM-0269': 2,
#  'images/CXR1423_IM-0270': 2,
#  'images/CXR1424_IM-0271': 2,
#  'images/CXR1425_IM-0272': 2,
#  'images/CXR1427_IM-0273': 1,
#  'images/CXR1428_IM-0274': 2,
#  'images/CXR1429_IM-0275': 2,
#  'images/CXR143_IM-0276': 2,
#  'images/CXR1430_IM-0277': 1,
#  'images/CXR1431_IM-0278': 2,
#  'images/CXR1432_IM-0278': 2,
#  'images/CXR1433_IM-0278': 2,
#  'images/CXR1434_IM-0279': 2,
#  'images/CXR1435_IM-0280': 2,
#  'images/CXR1436_IM-0280': 2,
#  'images/CXR1437_IM-0281': 2,
#  'images/CXR1438_IM-0282': 2,
#  'images/CXR1439_IM-0282': 2,
#  'images/CXR144_IM-0283': 1,
#  'images/CXR1440_IM-0284': 2,
#  'images/CXR1441_IM-0285': 2,
#  'images/CXR1442_IM-0286': 2,
#  'images/CXR1443_IM-0286': 2,
#  'images/CXR1444_IM-0286': 1,
#  'images/CXR1445_IM-0287': 2,
#  'images/CXR1447_IM-0289': 2,
#  'images/CXR1448_IM-0289': 2,
#  'images/CXR1449_IM-0290': 2,
#  'images/CXR145_IM-0290': 2,
#  'images/CXR1450_IM-0291': 2,
#  'images/CXR1451_IM-0291': 2,
#  'images/CXR1452_IM-0291': 2,
#  'images/CXR1453_IM-0292': 2,
#  'images/CXR1454_IM-0293': 2,
#  'images/CXR1455_IM-0293': 2,
#  'images/CXR1456_IM-0294': 2,
#  'images/CXR1457_IM-0295': 1,
#  'images/CXR1458_IM-0296': 2,
#  'images/CXR1459_IM-0297': 3,
#  'images/CXR1460_IM-0298': 2,
#  'images/CXR1461_IM-0299': 2,
#  'images/CXR1462_IM-0299': 2,
#  'images/CXR1463_IM-0300': 1,
#  'images/CXR1464_IM-0301': 2,
#  'images/CXR1465_IM-0302': 2,
#  'images/CXR1466_IM-0302': 2,
#  'images/CXR1467_IM-0302': 2,
#  'images/CXR1468_IM-0303': 2,
#  'images/CXR1469_IM-0303': 2,
#  'images/CXR147_IM-0303': 1,
#  'images/CXR1470_IM-0303': 2,
#  'images/CXR1471_IM-0304': 2,
#  'images/CXR1472_IM-0305': 2,
#  'images/CXR1473_IM-0306': 2,
#  'images/CXR1474_IM-0307': 2,
#  'images/CXR1475_IM-0307': 1,
#  'images/CXR1476_IM-0308': 2,
#  'images/CXR1477_IM-0309': 2,
#  'images/CXR1478_IM-0310-0001': 3,
#  'images/CXR1480_IM-0311': 2,
#  'images/CXR1481_IM-0312': 2,
#  'images/CXR1482_IM-0313': 1,
#  'images/CXR1483_IM-0313': 2,
#  'images/CXR1484_IM-0313': 2,
#  'images/CXR1485_IM-0313': 2,
#  'images/CXR1487_IM-0314': 2,
#  'images/CXR1488_IM-0315': 2,
#  'images/CXR1489_IM-0315': 2,
#  'images/CXR1491_IM-0317': 2,
#  'images/CXR1492_IM-0318': 2,
#  'images/CXR1497_IM-0321': 2,
#  'images/CXR1498_IM-0322': 2,
#  'images/CXR1499_IM-0323': 2,
#  'images/CXR15_IM-0324': 2,
#  'images/CXR150_IM-0325-0001': 2,
#  'images/CXR1500_IM-0326': 3,
#  'images/CXR1501_IM-0327': 2,
#  'images/CXR1502_IM-0328': 2,
#  'images/CXR1505_IM-0330': 2,
#  'images/CXR1506_IM-0330': 2,
#  'images/CXR1508_IM-0330': 2,
#  'images/CXR1509_IM-0331': 2,
#  'images/CXR151_IM-0331': 2,
#  'images/CXR1510_IM-0331': 2,
#  'images/CXR1511_IM-0331': 2,
#  'images/CXR1512_IM-0332': 2,
#  'images/CXR1513_IM-0333': 2,
#  'images/CXR1514_IM-0333': 2,
#  'images/CXR1515_IM-0333': 2,
#  'images/CXR1516_IM-0334': 2,
#  'images/CXR1517_IM-0335': 2,
#  'images/CXR1518_IM-0335': 2,
#  'images/CXR1519_IM-0335': 2,
#  'images/CXR152_IM-0335': 2,
#  'images/CXR1520_IM-0336': 2,
#  'images/CXR1521_IM-0337': 3,
#  'images/CXR1522_IM-0338-0001': 1,
#  'images/CXR1523_IM-0339': 3,
#  'images/CXR1524_IM-0339': 2,
#  'images/CXR1525_IM-0340': 4,
#  'images/CXR1526_IM-0341': 2,
#  'images/CXR1527_IM-0341-1001': 1,
#  'images/CXR1528_IM-0341': 2,
#  'images/CXR1529_IM-0342-0001': 2,
#  'images/CXR153_IM-0343': 2,
#  'images/CXR1530_IM-0344': 2,
#  'images/CXR1531_IM-0344': 2,
#  'images/CXR1532_IM-0344': 2,
#  'images/CXR1533_IM-0344': 2,
#  'images/CXR1534_IM-0345': 2,
#  'images/CXR1535_IM-0346': 2,
#  'images/CXR1537_IM-0348': 2,
#  'images/CXR1538_IM-0348': 2,
#  'images/CXR1539_IM-0349': 2,
#  'images/CXR154_IM-0350': 2,
#  'images/CXR1540_IM-0351': 2,
#  'images/CXR1542_IM-0352': 2,
#  'images/CXR1543_IM-0353': 2,
#  'images/CXR1544_IM-0354': 2,
#  'images/CXR1545_IM-0355': 2,
#  'images/CXR1546_IM-0356': 2,
#  'images/CXR1547_IM-0357': 2,
#  'images/CXR1548_IM-0357': 2,
#  'images/CXR1549_IM-0357': 1,
#  'images/CXR1550_IM-0359': 2,
#  'images/CXR1551_IM-0359': 2,
#  'images/CXR1552_IM-0360': 2,
#  'images/CXR1553_IM-0360': 2,
#  'images/CXR1554_IM-0361': 2,
#  'images/CXR1555_IM-0362': 2,
#  'images/CXR1556_IM-0363': 2,
#  'images/CXR1557_IM-0364': 1,
#  'images/CXR1558_IM-0365': 2,
#  'images/CXR1559_IM-0365': 2,
#  'images/CXR1560_IM-0366': 2,
#  'images/CXR1561_IM-0367': 2,
#  'images/CXR1562_IM-0367': 2,
#  'images/CXR1563_IM-0368': 2,
#  'images/CXR1564_IM-0368': 2,
#  'images/CXR1565_IM-0368': 2,
#  'images/CXR1567_IM-0370': 2,
#  'images/CXR1568_IM-0371': 2,
#  'images/CXR1569_IM-0372': 2,
#  'images/CXR157_IM-0372': 1,
#  'images/CXR1570_IM-0372': 2,
#  'images/CXR1571_IM-0373': 1,
#  'images/CXR1572_IM-0373': 2,
#  'images/CXR1573_IM-0374': 2,
#  'images/CXR1574_IM-0374': 2,
#  'images/CXR1576_IM-0375': 2,
#  'images/CXR1577_IM-0375': 2,
#  'images/CXR1578_IM-0376': 2,
#  'images/CXR1579_IM-0376': 1,
#  'images/CXR158_IM-0377': 2,
#  'images/CXR1580_IM-0378': 2,
#  'images/CXR1581_IM-0378': 2,
#  'images/CXR1582_IM-0378': 2,
#  'images/CXR1583_IM-0378': 2,
#  'images/CXR1584_IM-0379': 2,
#  'images/CXR1585_IM-0380': 2,
#  'images/CXR1586_IM-0380': 2,
#  'images/CXR1587_IM-0381': 2,
#  'images/CXR1588_IM-0382': 2,
#  'images/CXR1589_IM-0382': 2,
#  'images/CXR159_IM-0382': 2,
#  'images/CXR1590_IM-0383': 2,
#  'images/CXR1591_IM-0384': 2,
#  'images/CXR1592_IM-0385': 1,
#  'images/CXR1593_IM-0385': 2,
#  'images/CXR1594_IM-0385': 2,
#  'images/CXR1595_IM-0386': 2,
#  'images/CXR1596_IM-0387': 2,
#  'images/CXR1597_IM-0388': 2,
#  'images/CXR1598_IM-0389': 2,
#  'images/CXR1599_IM-0389': 2,
#  'images/CXR160_IM-0390': 2,
#  'images/CXR1600_IM-0390': 2,
#  'images/CXR1601_IM-0390': 2,
#  'images/CXR1603_IM-0391': 2,
#  'images/CXR1606_IM-0394': 1,
#  'images/CXR1607_IM-0394': 1,
#  'images/CXR1608_IM-0394': 2,
#  'images/CXR1609_IM-0394': 2,
#  'images/CXR161_IM-0394': 2,
#  'images/CXR1610_IM-0395': 3,
#  'images/CXR1612_IM-0397': 1,
#  'images/CXR1616_IM-0399': 2,
#  'images/CXR1617_IM-0399': 2,
#  'images/CXR1619_IM-0400': 2,
#  'images/CXR162_IM-0401': 2,
#  'images/CXR1620_IM-0402': 2,
#  'images/CXR1621_IM-0403': 2,
#  'images/CXR1622_IM-0404': 2,
#  'images/CXR1623_IM-0405': 2,
#  'images/CXR1624_IM-0406': 2,
#  'images/CXR1625_IM-0406': 2,
#  'images/CXR1626_IM-0407': 2,
#  'images/CXR1627_IM-0408': 2,
#  'images/CXR1629_IM-0409': 1,
#  'images/CXR163_IM-0410': 3,
#  'images/CXR1630_IM-0411': 2,
#  'images/CXR1631_IM-0412-0001': 2,
#  'images/CXR1632_IM-0413': 2,
#  'images/CXR1633_IM-0414': 3,
#  'images/CXR1634_IM-0414': 2,
#  'images/CXR1635_IM-0415': 2,
#  'images/CXR1636_IM-0415': 2,
#  'images/CXR1637_IM-0416': 1,
#  'images/CXR1638_IM-0417': 3,
#  'images/CXR1639_IM-0418': 2,
#  'images/CXR164_IM-0419': 2,
#  'images/CXR1640_IM-0420': 2,
#  'images/CXR1641_IM-0420': 2,
#  'images/CXR1642_IM-0421': 2,
#  'images/CXR1643_IM-0421': 3,
#  'images/CXR1644_IM-0422': 1,
#  'images/CXR1645_IM-0422': 2,
#  'images/CXR1646_IM-0423': 2,
#  'images/CXR1647_IM-0424': 2,
#  'images/CXR1648_IM-0425-0001': 2,
#  'images/CXR1649_IM-0426': 2,
#  'images/CXR165_IM-0427': 2,
#  'images/CXR1652_IM-0428': 2,
#  'images/CXR1653_IM-0429': 1,
#  'images/CXR1654_IM-0430': 2,
#  'images/CXR1655_IM-0431': 2,
#  'images/CXR1656_IM-0431': 2,
#  'images/CXR1657_IM-0432': 2,
#  'images/CXR1658_IM-0433': 1,
#  'images/CXR1659_IM-0434': 2,
#  'images/CXR166_IM-0435': 2,
#  'images/CXR1660_IM-0436': 2,
#  'images/CXR1662_IM-0438': 1,
#  'images/CXR1663_IM-0439': 2,
#  'images/CXR1665_IM-0439': 2,
#  'images/CXR1666_IM-0440-0001': 2,
#  'images/CXR1667_IM-0441': 2,
#  'images/CXR1668_IM-0441': 2,
#  'images/CXR1669_IM-0441': 2,
#  'images/CXR167_IM-0441': 2,
#  'images/CXR1670_IM-0441': 2,
#  'images/CXR1671_IM-0442': 2,
#  'images/CXR1673_IM-0444': 2,
#  'images/CXR1674_IM-0445': 2,
#  'images/CXR1675_IM-0445': 2,
#  'images/CXR1676_IM-0445': 2,
#  'images/CXR1677_IM-0446': 3,
#  'images/CXR1678_IM-0447-0001': 2,
#  'images/CXR1679_IM-0448': 2,
#  'images/CXR168_IM-0448': 2,
#  'images/CXR1681_IM-0448': 2,
#  'images/CXR1682_IM-0449': 2,
#  'images/CXR1683_IM-0449': 2,
#  'images/CXR1684_IM-0449': 2,
#  'images/CXR1685_IM-0449': 2,
#  'images/CXR1686_IM-0450': 2,
#  'images/CXR1687_IM-0450': 2,
#  'images/CXR1688_IM-0450': 2,
#  'images/CXR1689_IM-0451': 2,
#  'images/CXR169_IM-0452': 2,
#  'images/CXR1691_IM-0453': 2,
#  'images/CXR1693_IM-0454': 1,
#  'images/CXR1694_IM-0455': 2,
#  'images/CXR1695_IM-0456': 2,
#  'images/CXR1696_IM-0457': 2,
#  'images/CXR1697_IM-0458': 2,
#  'images/CXR1698_IM-0458': 2,
#  'images/CXR1699_IM-0459': 2,
#  'images/CXR17_IM-0460': 2,
#  'images/CXR1701_IM-0462': 2,
#  'images/CXR1702_IM-0463': 2,
#  'images/CXR1703_IM-0463': 2,
#  'images/CXR1704_IM-0464': 2,
#  'images/CXR1705_IM-0465': 1,
#  'images/CXR1706_IM-0466': 2,
#  'images/CXR1707_IM-0466': 2,
#  'images/CXR1708_IM-0466': 2,
#  'images/CXR1709_IM-0467': 2,
#  'images/CXR1710_IM-0469': 2,
#  'images/CXR1711_IM-0469': 2,
#  'images/CXR1712_IM-0470': 2,
#  'images/CXR1714_IM-0472': 1,
#  'images/CXR1715_IM-0473': 1,
#  'images/CXR1717_IM-0473': 2,
#  'images/CXR1718_IM-0474': 1,
#  'images/CXR1719_IM-0474': 2,
#  'images/CXR172_IM-0474': 2,
#  'images/CXR1720_IM-0475-0001': 2,
#  'images/CXR1720_IM-0475': 1,
#  'images/CXR1721_IM-0476': 2,
#  'images/CXR1722_IM-0476': 1,
#  'images/CXR1723_IM-0477': 2,
#  'images/CXR1724_IM-0478': 1,
#  'images/CXR1725_IM-0478': 2,
#  'images/CXR1726_IM-0479': 2,
#  'images/CXR1727_IM-0479': 2,
#  'images/CXR1728_IM-0479': 2,
#  'images/CXR1729_IM-0480': 2,
#  'images/CXR173_IM-0481': 2,
#  'images/CXR1730_IM-0481': 2,
#  'images/CXR1731_IM-0481': 2,
#  'images/CXR1732_IM-0482': 2,
#  'images/CXR1734_IM-0484': 2,
#  'images/CXR1735_IM-0484': 2,
#  'images/CXR1736_IM-0484': 2,
#  'images/CXR1737_IM-0485': 2,
#  'images/CXR1738_IM-0486': 2,
#  'images/CXR1739_IM-0487': 2,
#  'images/CXR174_IM-0488': 2,
#  'images/CXR1740_IM-0488': 2,
#  'images/CXR1742_IM-0489': 2,
#  'images/CXR1743_IM-0489': 2,
#  'images/CXR1744_IM-0489': 2,
#  'images/CXR1745_IM-0489': 2,
#  'images/CXR1747_IM-0490': 2,
#  'images/CXR1748_IM-0490': 2,
#  'images/CXR175_IM-0492': 1,
#  'images/CXR1750_IM-0493': 2,
#  'images/CXR1751_IM-0494': 2,
#  'images/CXR1752_IM-0494': 2,
#  'images/CXR1753_IM-0494': 2,
#  'images/CXR1757_IM-0495': 1,
#  'images/CXR1758_IM-0495': 2,
#  'images/CXR1759_IM-0495': 2,
#  'images/CXR176_IM-0496': 2,
#  'images/CXR1760_IM-0497': 2,
#  'images/CXR1763_IM-0497': 2,
#  'images/CXR1764_IM-0498': 1,
#  'images/CXR1765_IM-0499': 2,
#  'images/CXR1766_IM-0500': 2,
#  'images/CXR1767_IM-0501-0001': 2,
#  'images/CXR1768_IM-0502': 3,
#  'images/CXR1769_IM-0503': 1,
#  'images/CXR177_IM-0503': 2,
#  'images/CXR1770_IM-0504': 2,
#  'images/CXR1771_IM-0505': 2,
#  'images/CXR1774_IM-0507': 1,
#  'images/CXR1775_IM-0508': 2,
#  'images/CXR1776_IM-0508': 2,
#  'images/CXR1777_IM-0509': 2,
#  'images/CXR1779_IM-0509': 2,
#  'images/CXR178_IM-0509': 1,
#  'images/CXR1780_IM-0509': 2,
#  'images/CXR1781_IM-0509': 2,
#  'images/CXR1782_IM-0510': 2,
#  'images/CXR1785_IM-0512': 2,
#  'images/CXR1786_IM-0512': 2,
#  'images/CXR1787_IM-0513': 2,
#  'images/CXR1788_IM-0513': 2,
#  'images/CXR179_IM-0514': 2,
#  'images/CXR1790_IM-0515': 1,
#  'images/CXR1791_IM-0515': 2,
#  'images/CXR1792_IM-0515': 2,
#  'images/CXR1793_IM-0515': 1,
#  'images/CXR1794_IM-0515': 2,
#  'images/CXR1795_IM-0516': 2,
#  'images/CXR1796_IM-0517': 2,
#  'images/CXR1797_IM-0517': 2,
#  'images/CXR1799_IM-0519': 2,
#  'images/CXR18_IM-0520': 2,
#  'images/CXR1800_IM-0520': 2,
#  'images/CXR1801_IM-0520': 2,
#  'images/CXR1802_IM-0521': 2,
#  'images/CXR1804_IM-0522': 2,
#  'images/CXR1806_IM-0524': 1,
#  'images/CXR1807_IM-0524': 2,
#  'images/CXR1808_IM-0524': 2,
#  'images/CXR181_IM-0524': 2,
#  'images/CXR1810_IM-0524': 2,
#  'images/CXR1811_IM-0525': 1,
#  'images/CXR1812_IM-0525': 2,
#  'images/CXR1813_IM-0526': 2,
#  'images/CXR1815_IM-0527': 2,
#  'images/CXR1816_IM-0528': 2,
#  'images/CXR1817_IM-0529': 1,
#  'images/CXR182_IM-0531': 2,
#  'images/CXR1820_IM-0532': 2,
#  'images/CXR1821_IM-0532': 2,
#  'images/CXR1822_IM-0533': 2,
#  'images/CXR1823_IM-0534': 2,
#  'images/CXR1824_IM-0535': 1,
#  'images/CXR1826_IM-0535': 2,
#  'images/CXR1827_IM-0535': 2,
#  'images/CXR1829_IM-0537': 2,
#  'images/CXR183_IM-0537': 2,
#  'images/CXR1830_IM-0537': 1,
#  'images/CXR1831_IM-0538': 2,
#  'images/CXR1832_IM-0538': 2,
#  'images/CXR1833_IM-0539': 2,
#  'images/CXR1834_IM-0539': 2,
#  'images/CXR1835_IM-0539': 2,
#  'images/CXR1836_IM-0540': 2,
#  'images/CXR1837_IM-0541': 1,
#  'images/CXR1838_IM-0542': 1,
#  'images/CXR1839_IM-0543': 2,
#  'images/CXR184_IM-0544': 2,
#  'images/CXR1840_IM-0545': 2,
#  'images/CXR1841_IM-0545': 2,
#  'images/CXR1843_IM-0546': 1,
#  'images/CXR1844_IM-0547': 2,
#  'images/CXR1846_IM-0549': 2,
#  'images/CXR1847_IM-0550': 2,
#  'images/CXR1848_IM-0550': 2,
#  'images/CXR1849_IM-0550': 2,
#  'images/CXR185_IM-0551': 2,
#  'images/CXR1850_IM-0552': 1,
#  'images/CXR1851_IM-0553': 2,
#  'images/CXR1852_IM-0554': 2,
#  'images/CXR1853_IM-0555': 2,
#  'images/CXR1854_IM-0555': 2,
#  'images/CXR1855_IM-0555': 2,
#  'images/CXR1856_IM-0556': 1,
#  'images/CXR1857_IM-0556': 2,
#  'images/CXR186_IM-0558': 2,
#  'images/CXR1860_IM-0558': 2,
#  'images/CXR1861_IM-0558': 2,
#  'images/CXR1863_IM-0558': 2,
#  'images/CXR1864_IM-0558': 2,
#  'images/CXR1865_IM-0558': 2,
#  'images/CXR1866_IM-0559': 2,
#  'images/CXR1867_IM-0560': 2,
#  'images/CXR1868_IM-0561': 2,
#  'images/CXR187_IM-0563': 2,
#  'images/CXR1870_IM-0563': 2,
#  'images/CXR1871_IM-0564': 2,
#  'images/CXR1872_IM-0565': 1,
#  'images/CXR1873_IM-0565': 2,
#  'images/CXR1874_IM-0565': 2,
#  'images/CXR1875_IM-0566': 2,
#  'images/CXR1876_IM-0567': 2,
#  'images/CXR1877_IM-0568': 2,
#  'images/CXR1878_IM-0569': 2,
#  'images/CXR1879_IM-0569': 2,
#  'images/CXR1880_IM-0569': 1,
#  'images/CXR1881_IM-0570': 2,
#  'images/CXR1882_IM-0571': 2,
#  'images/CXR1883_IM-0572': 2,
#  'images/CXR1884_IM-0573': 3,
#  'images/CXR1885_IM-0574': 2,
#  'images/CXR1886_IM-0574': 2,
#  'images/CXR1887_IM-0575': 1,
#  'images/CXR1888_IM-0576': 2,
#  'images/CXR1889_IM-0577': 2,
#  'images/CXR189_IM-0578': 2,
#  'images/CXR1891_IM-0580': 2,
#  'images/CXR1892_IM-0580': 2,
#  'images/CXR1893_IM-0580': 2,
#  'images/CXR1894_IM-0581': 2,
#  'images/CXR1895_IM-0581': 2,
#  'images/CXR1896_IM-0581': 2,
#  'images/CXR1897_IM-0581': 1,
#  'images/CXR1898_IM-0581': 2,
#  'images/CXR1899_IM-0582': 2,
#  'images/CXR19_IM-0583': 2,
#  'images/CXR190_IM-0583': 2,
#  'images/CXR1900_IM-0584': 2,
#  'images/CXR1901_IM-0585': 2,
#  'images/CXR1902_IM-0586': 2,
#  'images/CXR1903_IM-0586': 2,
#  'images/CXR1905_IM-0587': 2,
#  'images/CXR1908_IM-0590': 2,
#  'images/CXR1909_IM-0590': 2,
#  'images/CXR191_IM-0591': 2,
#  'images/CXR1911_IM-0593': 2,
#  'images/CXR1912_IM-0594': 2,
#  'images/CXR1913_IM-0595': 2,
#  'images/CXR1914_IM-0595': 2,
#  'images/CXR1915_IM-0595': 2,
#  'images/CXR1916_IM-0595': 2,
#  'images/CXR1918_IM-0597': 2,
#  'images/CXR1919_IM-0598': 3,
#  'images/CXR192_IM-0598': 2,
#  'images/CXR1920_IM-0598': 2,
#  'images/CXR1921_IM-0598': 2,
#  'images/CXR1922_IM-0598': 2,
#  'images/CXR1923_IM-0598': 2,
#  'images/CXR1924_IM-0598': 2,
#  'images/CXR1925_IM-0599': 2,
#  'images/CXR1926_IM-0600': 2,
#  'images/CXR1927_IM-0600': 2,
#  'images/CXR1928_IM-0600': 2,
#  'images/CXR1929_IM-0600': 2,
#  'images/CXR193_IM-0601': 2,
#  'images/CXR1930_IM-0602-1001': 2,
#  'images/CXR1931_IM-0602': 2,
#  'images/CXR1932_IM-0603': 2,
#  'images/CXR1933_IM-0604': 2,
#  'images/CXR1934_IM-0604': 2,
#  'images/CXR1935_IM-0605-0001': 2,
#  'images/CXR1936_IM-0606': 2,
#  'images/CXR1937_IM-0607': 2,
#  'images/CXR1938_IM-0608': 2,
#  'images/CXR1939_IM-0609': 1,
#  'images/CXR194_IM-0609': 2,
#  'images/CXR1940_IM-0610': 2,
#  'images/CXR1941_IM-0610': 1,
#  'images/CXR1942_IM-0611-0001': 1,
#  'images/CXR1943_IM-0612': 2,
#  'images/CXR1946_IM-0615': 2,
#  'images/CXR1947_IM-0616': 2,
#  'images/CXR1948_IM-0616': 2,
#  'images/CXR195_IM-0618': 2,
#  'images/CXR1950_IM-0618': 2,
#  'images/CXR1951_IM-0619': 2,
#  'images/CXR1952_IM-0620': 1,
#  'images/CXR1953_IM-0621': 2,
#  'images/CXR1954_IM-0622': 2,
#  'images/CXR1956_IM-0623': 2,
#  'images/CXR1957_IM-0624': 2,
#  'images/CXR1958_IM-0625': 2,
#  'images/CXR1959_IM-0625': 2,
#  'images/CXR196_IM-0626': 1,
#  'images/CXR1960_IM-0627': 2,
#  'images/CXR1961_IM-0628': 2,
#  'images/CXR1962_IM-0628': 2,
#  'images/CXR1963_IM-0629': 2,
#  'images/CXR1964_IM-0629': 2,
#  'images/CXR1965_IM-0629': 2,
#  'images/CXR1966_IM-0629': 2,
#  'images/CXR1967_IM-0629': 2,
#  'images/CXR1968_IM-0630': 2,
#  'images/CXR197_IM-0631': 2,
#  'images/CXR1970_IM-0632': 2,
#  'images/CXR1972_IM-0633': 2,
#  'images/CXR1973_IM-0633': 2,
#  'images/CXR1974_IM-0633': 2,
#  'images/CXR1978_IM-0636': 2,
#  'images/CXR1979_IM-0637': 2,
#  'images/CXR198_IM-0637': 1,
#  'images/CXR1980_IM-0637': 2,
#  'images/CXR1981_IM-0638': 2,
#  'images/CXR1984_IM-0641-4001': 2,
#  'images/CXR1985_IM-0642': 2,
#  'images/CXR1986_IM-0643': 1,
#  'images/CXR1987_IM-0644': 2,
#  'images/CXR1990_IM-0648': 2,
#  'images/CXR1991_IM-0648': 2,
#  'images/CXR1992_IM-0649': 2,
#  'images/CXR1993_IM-0650': 2,
#  'images/CXR1994_IM-0651': 2,
#  'images/CXR1995_IM-0651': 2,
#  'images/CXR1997_IM-0651': 2,
#  'images/CXR1999_IM-0651': 2,
#  'images/CXR2_IM-0652': 2,
#  'images/CXR20_IM-0653': 2,
#  'images/CXR200_IM-0653': 2,
#  'images/CXR2000_IM-0654': 2,
#  'images/CXR2002_IM-0654': 2,
#  'images/CXR2003_IM-0654': 2,
#  'images/CXR2005_IM-0656': 2,
#  'images/CXR2006_IM-0656': 2,
#  'images/CXR2007_IM-0657-0001': 2,
#  'images/CXR2008_IM-0658': 2,
#  'images/CXR201_IM-0660': 2,
#  'images/CXR2011_IM-0661': 2,
#  'images/CXR2012_IM-0662': 2,
#  'images/CXR2013_IM-0663': 2,
#  'images/CXR2014_IM-0664': 2,
#  'images/CXR2015_IM-0664': 2,
#  'images/CXR2016_IM-0665': 2,
#  'images/CXR2017_IM-0665': 2,
#  'images/CXR2019_IM-0666': 2,
#  'images/CXR202_IM-0667': 2,
#  'images/CXR2020_IM-0668': 2,
#  'images/CXR2021_IM-0668': 2,
#  'images/CXR2022_IM-0669': 2,
#  'images/CXR2023_IM-0669': 2,
#  'images/CXR2025_IM-0671': 1,
#  'images/CXR2026_IM-0671': 2,
#  'images/CXR2027_IM-0672-0001': 2,
#  'images/CXR2028_IM-0673': 2,
#  'images/CXR2029_IM-0674': 2,
#  'images/CXR203_IM-0675': 1,
#  'images/CXR2030_IM-0675': 2,
#  'images/CXR2031_IM-0676': 2,
#  'images/CXR2032_IM-0677': 2,
#  'images/CXR2033_IM-0678': 2,
#  'images/CXR2034_IM-0679': 2,
#  'images/CXR2035_IM-0680': 1,
#  'images/CXR2036_IM-0680': 2,
#  'images/CXR2038_IM-0682': 2,
#  'images/CXR2039_IM-0683': 2,
#  'images/CXR204_IM-0683': 1,
#  'images/CXR2041_IM-0685': 3,
#  'images/CXR2044_IM-0687': 2,
#  'images/CXR2045_IM-0687': 2,
#  'images/CXR2046_IM-0688': 2,
#  'images/CXR2047_IM-0688': 2,
#  'images/CXR2048_IM-0688': 2,
#  'images/CXR2052_IM-0690': 2,
#  'images/CXR2053_IM-0691': 2,
#  'images/CXR2056_IM-0694-1001': 2,
#  'images/CXR2058_IM-0696': 2,
#  'images/CXR2059_IM-0696': 2,
#  'images/CXR206_IM-0697': 1,
#  'images/CXR2060_IM-0698': 2,
#  'images/CXR2061_IM-0698': 2,
#  'images/CXR2062_IM-0699-0001': 2,
#  'images/CXR2065_IM-0701': 2,
#  'images/CXR2066_IM-0701': 2,
#  'images/CXR2067_IM-0701': 2,
#  'images/CXR2068_IM-0701': 2,
#  'images/CXR2069_IM-0702': 2,
#  'images/CXR207_IM-0703': 2,
#  'images/CXR2070_IM-0704': 2,
#  ...}

# %%
len(images)
# Out:
# 3350

# %%
def train_test_split(data):
    persons = list(data.keys())
    persons_train = persons[:2500]
    persons_cv = persons[2500:3000]
    persons_test = persons[3000:3350]
    return persons_train, persons_cv, persons_test

# %%
images_train, images_cv, images_test = train_test_split(images)

# %%
def combining_images(image_set):
    
    image_per_person = defaultdict(list)  # creating a list of dictionary to store all the image paths
                                            #corresponding to a person_id
    for pid in image_set:
        for img in dataset['Image_path'].values:
            if pid in img:
                image_per_person[pid].append(img)
            else:
                continue
    return image_per_person

# %%
img_per_person_train = combining_images(images_train)
img_per_person_cv = combining_images(images_cv)
img_per_person_test = combining_images(images_test)

# %%
len(img_per_person_train), len(images_train)
# Out:
# (2500, 2500)

# %%
img_per_person_train['images/CXR1001_IM-0004']
# Out:
# ['images/CXR1001_IM-0004-1001.png', 'images/CXR1001_IM-0004-1002.png']

# %%
def load_image(file):
    img = tf.io.read_file(file)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return img

# %%
# just checking the ID which has 4 images
for k,v in images.items():
    if v == 4:
        print(k)
        break
# Out:
# images/CXR1102_IM-0069

# %%
plt.figure(figsize=(9,9))
plt.subplot(221)
plt.imshow(load_image('images/CXR1102_IM-0069-12012.png'))
plt.title('images/CXR1102_IM-0069-12012.png')
plt.subplot(222)
plt.imshow(load_image('images/CXR1102_IM-0069-2001.png'))
plt.title('images/CXR1102_IM-0069-2001.png')
plt.subplot(223)
plt.imshow(load_image('images/CXR1102_IM-0069-3001.png'))
plt.title('images/CXR1102_IM-0069-3001.png')
plt.subplot(224)
plt.imshow(load_image('images/CXR1102_IM-0069-4004.png'))
plt.title('images/CXR1102_IM-0069-4004.png')
# Out:
# Text(0.5, 1.0, 'images/CXR1102_IM-0069-4004.png')

# %% [markdown]
# 2 side view and 2 front view images for the same ID
#
# Sample chest scans of a person(4 images)
#
# Now, we have multiple chest scans to produce a single report. Some person_ids have 1, some have 2 and the highest is 4. So we can take pairs of those images as input. If it has only one image, then it can be replicated.

# %%
def create_data(image_per_person):
    # new dataset
    person_id, image1, image2, report = [],[],[],[]
    for pid, imgs in image_per_person.items():   #contains pid and the images associated with that pid

        if len(imgs) == 1:
            image1.append(imgs[0])
            image2.append(imgs[0])
            person_id.append(pid)
            report.append(findings[pid])
        else:
            num = 0
            a = itertools.combinations(imgs, 2)
            for i in a:
                image1.append(i[0])
                image2.append(i[1])
                person_id.append(pid + '_' + str(num))
                report.append(findings[pid])
                num += 1
    data = pd.DataFrame()
    data['Person_id'] = person_id
    data['Image1'] = image1
    data['Image2'] = image2
    data['Report'] = report
    
    return data

# %%
train = create_data(img_per_person_train)
test = create_data(img_per_person_test)
cv = create_data(img_per_person_cv)

# %%
train.head()
# Out:
#                   Person_id                           Image1  \
# 0   images/CXR1_1_IM-0001_0   images/CXR1_1_IM-0001-3001.png
# 1    images/CXR10_IM-0002_0    images/CXR10_IM-0002-1001.png
# 2   images/CXR100_IM-0002_0   images/CXR100_IM-0002-1001.png
# 3  images/CXR1000_IM-0003_0  images/CXR1000_IM-0003-1001.png
# 4  images/CXR1000_IM-0003_1  images/CXR1000_IM-0003-1001.png
#
#                             Image2  \
# 0   images/CXR1_1_IM-0001-4001.png
# 1    images/CXR10_IM-0002-2001.png
# 2   images/CXR100_IM-0002-2001.png
# 3  images/CXR1000_IM-0003-2001.png
# 4  images/CXR1000_IM-0003-3001.png
#
#                                               Report
# 0  The cardiac silhouette and mediastinum size ar...
# 1  The cardiomediastinal silhouette is within nor...
# 2  Both lungs are clear and expanded. Heart and m...
# 3  There is XXXX increased opacity within the rig...
# 4  There is XXXX increased opacity within the rig...

# %% [markdown]
# ### Text Cleaning

# %%
def lowercase(text):
    '''Converts to lowercase'''
    new_text = []
    for line in text:
        new_text.append(line.lower())
    return new_text

def decontractions(text):
    '''Performs decontractions in the doc'''
    new_text = []
    for phrase in text:
        phrase = re.sub(r"won't", "will not", phrase)
        phrase = re.sub(r"can\'t", "can not", phrase)
        phrase = re.sub(r"couldn\'t", "could not", phrase)
        phrase = re.sub(r"shouldn\'t", "should not", phrase)
        phrase = re.sub(r"wouldn\'t", "would not", phrase)
        # general
        phrase = re.sub(r"n\'t", " not", phrase)
        phrase = re.sub(r"\'re", " are", phrase)
        phrase = re.sub(r"\'s", " is", phrase)
        phrase = re.sub(r"\'d", " would", phrase)
        phrase = re.sub(r"\'ll", " will", phrase)
        phrase = re.sub(r"\'t", " not", phrase)
        phrase = re.sub(r"\'ve", " have", phrase)
        phrase = re.sub(r"\'m", " am", phrase)
        phrase = re.sub(r"\*+", "abuse", phrase)
        new_text.append(phrase)

    return new_text

def rem_punctuations(text):
    '''Removes punctuations'''
    punctuations = '''!()-[]{};:'"\,<>/?@#$%^&*~''' # full stop is not removed
    new_text = []
    for line in text:
        for char in line:
            if char in punctuations: 
                line = line.replace(char, "")
        new_text.append(' '.join(e for e in line.split()))
    return new_text

def rem_numbers(text):
    '''Removes numbers and irrelevant text like xxxx*'''
    new_text = []
    for line in text:
        temp = re.sub(r'x*','',line)
        new_text.append(re.sub(r'\d','',temp))
    return new_text

def words_filter(text):
    '''Removes words less than 2 characters except no and ct'''
    new_text = []
    for line in text:
        temp = line.split()
        temp2 = []
        for word in temp:
            if  len(word) <=2 and word != 'no' and word != 'ct':
                continue
            else:
                temp2.append(word)
        new_text.append(' '.join(e for e in temp2))
    return new_text

def multiple_fullstops(text):
    ''' Removes multiple full stops from the text'''
    new_text = []
    for line in text:
        new_text.append(re.sub(r'\.\.+', '.', line))
    return new_text

def fullstops(text):
    new_text = []
    for line in text:
        new_text.append(re.sub('\.', ' .', line))
    return new_text

def multiple_spaces(text):
    new_text = []
    for line in text:
        new_text.append(' '.join(e for e in line.split()))
    return new_text

def separting_startg_words(text):
    new_text = []
    for line in text:
        temp = []
        words = line.split()
        for i in words:
            if i.startswith('.') == False:
                temp.append(i)
            else:
                w = i.replace('.','. ')
                temp.append(w)
        new_text.append(' '.join(e for e in temp))
    return new_text

def rem_apostrophes(text):
    new_text = []
    for line in text:
        new_text.append(re.sub("'",'',line))
    return new_text

# %%
def text_preprocessing(text):
    '''Combines all the preprocess functions'''
    new_text = lowercase(text)
    new_text = decontractions(new_text)
    new_text = rem_punctuations(new_text)
    new_text = rem_numbers(new_text)
    new_text = words_filter(new_text)
    new_text = multiple_fullstops(new_text)
    new_text = fullstops(new_text)
    new_text = multiple_spaces(new_text)
    new_text = separting_startg_words(new_text)
    new_text = rem_apostrophes(new_text)
    return new_text

# %%
train['Report'] = text_preprocessing(train['Report'])
test['Report'] = text_preprocessing(test['Report'])
cv['Report'] = text_preprocessing(cv['Report'])

# %%
train.head()
# Out:
#                   Person_id                           Image1  \
# 0   images/CXR1_1_IM-0001_0   images/CXR1_1_IM-0001-3001.png
# 1    images/CXR10_IM-0002_0    images/CXR10_IM-0002-1001.png
# 2   images/CXR100_IM-0002_0   images/CXR100_IM-0002-1001.png
# 3  images/CXR1000_IM-0003_0  images/CXR1000_IM-0003-1001.png
# 4  images/CXR1000_IM-0003_1  images/CXR1000_IM-0003-1001.png
#
#                             Image2  \
# 0   images/CXR1_1_IM-0001-4001.png
# 1    images/CXR10_IM-0002-2001.png
# 2   images/CXR100_IM-0002-2001.png
# 3  images/CXR1000_IM-0003-2001.png
# 4  images/CXR1000_IM-0003-3001.png
#
#                                               Report
# 0  the cardiac silhouette and mediastinum size ar...
# 1  the cardiomediastinal silhouette within normal...
# 2  both lungs are clear and epanded .  heart and ...
# 3  there increased opacity within the right upper...
# 4  there increased opacity within the right upper...

# %%
l = [len(e.split()) for e in train['Report'].values]  # Number of words in each report

# %%
max(l)
# Out:
# 153

# %%
plt.title('Number of Words per Report')
sns.scatterplot(range(train.shape[0]), l)
plt.ylabel('Number of words')
# Out:
# C:\Users\DELL\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Number of words')

# %% [markdown]
# Most of the reports contain word count below 100

# %%
l = []
for i in train['Report'].values:
    l.extend(i.split())

# %%
c = Counter(l)

# %%
words = []
count = []
for k,v in c.items():
    words.append(k)
    count.append(v)
words_count = list(zip(count, words))

# %%
top_50_words = sorted(words_count)[::-1][:50]
bottom_50_words = sorted(words_count)[:50]

# %%
plt.figure(figsize=(15,5))
plt.bar(range(50), [c for c,w in top_50_words])
plt.title('Top 50 Most Occuring Words')
plt.xlabel('Words')
plt.ylabel('Count')
plt.xticks(ticks=range(50), labels=[w for c,w in top_50_words], rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x1fc327d0760>,
#   <matplotlib.axis.XTick at 0x1fc327d0730>,
#   <matplotlib.axis.XTick at 0x1fc327ca3d0>,
#   <matplotlib.axis.XTick at 0x1fc3285f730>,
#   <matplotlib.axis.XTick at 0x1fc3285fe80>,
#   <matplotlib.axis.XTick at 0x1fc32869610>,
#   <matplotlib.axis.XTick at 0x1fc3285fb20>,
#   <matplotlib.axis.XTick at 0x1fc32869280>,
#   <matplotlib.axis.XTick at 0x1fc3286f3d0>,
#   <matplotlib.axis.XTick at 0x1fc3286fb20>,
#   <matplotlib.axis.XTick at 0x1fc328762b0>,
#   <matplotlib.axis.XTick at 0x1fc32876a00>,
#   <matplotlib.axis.XTick at 0x1fc3287d190>,
#   <matplotlib.axis.XTick at 0x1fc32876640>,
#   <matplotlib.axis.XTick at 0x1fc3286f340>,
#   <matplotlib.axis.XTick at 0x1fc3287d580>,
#   <matplotlib.axis.XTick at 0x1fc3287dcd0>,
#   <matplotlib.axis.XTick at 0x1fc32883460>,
#   <matplotlib.axis.XTick at 0x1fc32883bb0>,
#   <matplotlib.axis.XTick at 0x1fc32883e80>,
#   <matplotlib.axis.XTick at 0x1fc3287dd90>,
#   <matplotlib.axis.XTick at 0x1fc32876550>,
#   <matplotlib.axis.XTick at 0x1fc32888850>,
#   <matplotlib.axis.XTick at 0x1fc32891070>,
#   <matplotlib.axis.XTick at 0x1fc32891730>,
#   <matplotlib.axis.XTick at 0x1fc32891e80>,
#   <matplotlib.axis.XTick at 0x1fc32891af0>,
#   <matplotlib.axis.XTick at 0x1fc32888f10>,
#   <matplotlib.axis.XTick at 0x1fc3287d850>,
#   <matplotlib.axis.XTick at 0x1fc328956a0>,
#   <matplotlib.axis.XTick at 0x1fc32895df0>,
#   <matplotlib.axis.XTick at 0x1fc328a0580>,
#   <matplotlib.axis.XTick at 0x1fc328a0cd0>,
#   <matplotlib.axis.XTick at 0x1fc328a05e0>,
#   <matplotlib.axis.XTick at 0x1fc328767c0>,
#   <matplotlib.axis.XTick at 0x1fc328a7100>,
#   <matplotlib.axis.XTick at 0x1fc328a7850>,
#   <matplotlib.axis.XTick at 0x1fc328af070>,
#   <matplotlib.axis.XTick at 0x1fc328af730>,
#   <matplotlib.axis.XTick at 0x1fc328a7d60>,
#   <matplotlib.axis.XTick at 0x1fc3287da30>,
#   <matplotlib.axis.XTick at 0x1fc328afb20>,
#   <matplotlib.axis.XTick at 0x1fc328b7340>,
#   <matplotlib.axis.XTick at 0x1fc328b7a90>,
#   <matplotlib.axis.XTick at 0x1fc328bb220>,
#   <matplotlib.axis.XTick at 0x1fc328bb970>,
#   <matplotlib.axis.XTick at 0x1fc328b7b50>,
#   <matplotlib.axis.XTick at 0x1fc32888be0>,
#   <matplotlib.axis.XTick at 0x1fc328bb2e0>,
#   <matplotlib.axis.XTick at 0x1fc328c4610>],
#  [Text(0, 0, '.'),
#   Text(1, 0, 'the'),
#   Text(2, 0, 'no'),
#   Text(3, 0, 'are'),
#   Text(4, 0, 'normal'),
#   Text(5, 0, 'and'),
#   Text(6, 0, 'pleural'),
#   Text(7, 0, 'there'),
#   Text(8, 0, 'pneumothora'),
#   Text(9, 0, 'effusion'),
#   Text(10, 0, 'heart'),
#   Text(11, 0, 'lungs'),
#   Text(12, 0, 'size'),
#   Text(13, 0, 'focal'),
#   Text(14, 0, 'within'),
#   Text(15, 0, 'clear'),
#   Text(16, 0, 'limits'),
#   Text(17, 0, 'pulmonary'),
#   Text(18, 0, 'consolidation'),
#   Text(19, 0, 'silhouette'),
#   Text(20, 0, 'right'),
#   Text(21, 0, 'mediastinal'),
#   Text(22, 0, 'airspace'),
#   Text(23, 0, 'cardiomediastinal'),
#   Text(24, 0, 'left'),
#   Text(25, 0, 'acute'),
#   Text(26, 0, 'lung'),
#   Text(27, 0, 'with'),
#   Text(28, 0, 'unremarkable'),
#   Text(29, 0, 'disease'),
#   Text(30, 0, 'stable'),
#   Text(31, 0, 'spine'),
#   Text(32, 0, 'mediastinum'),
#   Text(33, 0, 'structures'),
#   Text(34, 0, 'changes'),
#   Text(35, 0, 'contours'),
#   Text(36, 0, 'thoracic'),
#   Text(37, 0, 'bony'),
#   Text(38, 0, 'contour'),
#   Text(39, 0, 'mild'),
#   Text(40, 0, 'degenerative'),
#   Text(41, 0, 'large'),
#   Text(42, 0, 'seen'),
#   Text(43, 0, 'appear'),
#   Text(44, 0, 'opacity'),
#   Text(45, 0, 'osseous'),
#   Text(46, 0, 'without'),
#   Text(47, 0, 'calcified'),
#   Text(48, 0, 'cardiac'),
#   Text(49, 0, 'effusions')])

# %%
plt.figure(figsize=(15,5))
plt.bar(range(50), [c for c,w in bottom_50_words])
plt.title('Top 50 Least Occuring Words')
plt.xlabel('Words')
plt.ylabel('Count')
plt.xticks(ticks=range(50), labels=[w for c,w in bottom_50_words], rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x1fc32aafc10>,
#   <matplotlib.axis.XTick at 0x1fc32aafbe0>,
#   <matplotlib.axis.XTick at 0x1fc32aaf310>,
#   <matplotlib.axis.XTick at 0x1fc32970be0>,
#   <matplotlib.axis.XTick at 0x1fc3297c370>,
#   <matplotlib.axis.XTick at 0x1fc3297cac0>,
#   <matplotlib.axis.XTick at 0x1fc3297cd90>,
#   <matplotlib.axis.XTick at 0x1fc32970ca0>,
#   <matplotlib.axis.XTick at 0x1fc32982760>,
#   <matplotlib.axis.XTick at 0x1fc32989040>,
#   <matplotlib.axis.XTick at 0x1fc32989640>,
#   <matplotlib.axis.XTick at 0x1fc32989d90>,
#   <matplotlib.axis.XTick at 0x1fc32990520>,
#   <matplotlib.axis.XTick at 0x1fc329898b0>,
#   <matplotlib.axis.XTick at 0x1fc329827c0>,
#   <matplotlib.axis.XTick at 0x1fc32990a30>,
#   <matplotlib.axis.XTick at 0x1fc329981c0>,
#   <matplotlib.axis.XTick at 0x1fc32998910>,
#   <matplotlib.axis.XTick at 0x1fc3299b0a0>,
#   <matplotlib.axis.XTick at 0x1fc32998cd0>,
#   <matplotlib.axis.XTick at 0x1fc32990ca0>,
#   <matplotlib.axis.XTick at 0x1fc3299b790>,
#   <matplotlib.axis.XTick at 0x1fc3299bd90>,
#   <matplotlib.axis.XTick at 0x1fc329a7520>,
#   <matplotlib.axis.XTick at 0x1fc329a7c70>,
#   <matplotlib.axis.XTick at 0x1fc329ad400>,
#   <matplotlib.axis.XTick at 0x1fc329a7a00>,
#   <matplotlib.axis.XTick at 0x1fc32982c70>,
#   <matplotlib.axis.XTick at 0x1fc329ad190>,
#   <matplotlib.axis.XTick at 0x1fc329b50a0>,
#   <matplotlib.axis.XTick at 0x1fc329b57f0>,
#   <matplotlib.axis.XTick at 0x1fc329ba0a0>,
#   <matplotlib.axis.XTick at 0x1fc329ba6d0>,
#   <matplotlib.axis.XTick at 0x1fc329b5580>,
#   <matplotlib.axis.XTick at 0x1fc329ad0a0>,
#   <matplotlib.axis.XTick at 0x1fc32982310>,
#   <matplotlib.axis.XTick at 0x1fc329babb0>,
#   <matplotlib.axis.XTick at 0x1fc329c4340>,
#   <matplotlib.axis.XTick at 0x1fc329c4a90>,
#   <matplotlib.axis.XTick at 0x1fc329c4d60>,
#   <matplotlib.axis.XTick at 0x1fc329bae80>,
#   <matplotlib.axis.XTick at 0x1fc329b5490>,
#   <matplotlib.axis.XTick at 0x1fc329cb6a0>,
#   <matplotlib.axis.XTick at 0x1fc329cbdf0>,
#   <matplotlib.axis.XTick at 0x1fc329d1580>,
#   <matplotlib.axis.XTick at 0x1fc329d1cd0>,
#   <matplotlib.axis.XTick at 0x1fc329d1940>,
#   <matplotlib.axis.XTick at 0x1fc329cb6d0>,
#   <matplotlib.axis.XTick at 0x1fc329d82b0>,
#   <matplotlib.axis.XTick at 0x1fc329d8970>],
#  [Text(0, 0, 'abut'),
#   Text(1, 0, 'accentuates'),
#   Text(2, 0, 'accessed'),
#   Text(3, 0, 'accessory'),
#   Text(4, 0, 'activeacute'),
#   Text(5, 0, 'acuity'),
#   Text(6, 0, 'after'),
#   Text(7, 0, 'airfluid'),
#   Text(8, 0, 'all'),
#   Text(9, 0, 'already'),
#   Text(10, 0, 'although'),
#   Text(11, 0, 'aneurysm'),
#   Text(12, 0, 'angulate'),
#   Text(13, 0, 'annular'),
#   Text(14, 0, 'anteriorly'),
#   Text(15, 0, 'anterolateral'),
#   Text(16, 0, 'aorticopulmonary'),
#   Text(17, 0, 'appreciable'),
#   Text(18, 0, 'appropriate'),
#   Text(19, 0, 'arterial'),
#   Text(20, 0, 'arthroplasty'),
#   Text(21, 0, 'articular'),
#   Text(22, 0, 'artifactually'),
#   Text(23, 0, 'asbestos'),
#   Text(24, 0, 'aside'),
#   Text(25, 0, 'aspiration'),
#   Text(26, 0, 'assessment'),
#   Text(27, 0, 'atelectaticfibrotic'),
#   Text(28, 0, 'atriumcavoatrial'),
#   Text(29, 0, 'attached'),
#   Text(30, 0, 'avn'),
#   Text(31, 0, 'balloon'),
#   Text(32, 0, 'believed'),
#   Text(33, 0, 'benefit'),
#   Text(34, 0, 'bihilar'),
#   Text(35, 0, 'biliary'),
#   Text(36, 0, 'bipolar'),
#   Text(37, 0, 'biventricular'),
#   Text(38, 0, 'bodylateral'),
#   Text(39, 0, 'bordered'),
#   Text(40, 0, 'bridging'),
#   Text(41, 0, 'broken'),
#   Text(42, 0, 'bronchi'),
#   Text(43, 0, 'bronchial'),
#   Text(44, 0, 'bronchiectasis'),
#   Text(45, 0, 'bronchiectatic'),
#   Text(46, 0, 'bronchopulmonary'),
#   Text(47, 0, 'calcaneal'),
#   Text(48, 0, 'calcium'),
#   Text(49, 0, 'cardiophrenic')])

# %%
def remodelling(x):
    '''adds start and end tokens to a sentence '''
    return 'startseq' + ' ' + x + ' ' + 'endseq'

# %%
train['Report'] = train['Report'].apply(lambda x : remodelling(x))
test['Report'] = test['Report'].apply(lambda x : remodelling(x))
cv['Report'] = cv['Report'].apply(lambda x : remodelling(x))

# %%
# save the cleaned data(STRUCTURED DATA)
train.to_csv('Train_Data.csv', index=False)
test.to_csv('Test_Data.csv', index=False)
cv.to_csv('CV_Data.csv', index=False)
